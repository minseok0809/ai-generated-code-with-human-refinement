# %% [markdown]
# ### Extract Diplomatic Country List

# %% [markdown]
# [대한민국 외교부 2019 세계각국편람](https://www.mofa.go.kr/www/brd/m_4099/view.do?seq=367610)

# %% [markdown]
# #### 아주지역

# %%
text = """1. 아프가니스탄(Afghanistan) ······································································16
2. 호주(Australia) ·······················································································19
3. 방글라데시(Bangladesh) ·········································································25
4. 부탄(Bhutan) ·························································································30
5. 브루나이(Brunei) ····················································································34
6. 캄보디아(Cambodia) ··············································································37
7. 중국(China) ···························································································40
8. 쿡제도(Cook Islands) ·············································································44
9. 피지(Fiji) ································································································46
10. 인도(India) ···························································································50
11. 인도네시아(Indonesia) ··········································································55
12. 일본(Japan) ·························································································60
13. 키리바시(Kiribati) ··················································································65
14. 라오스(Laos) ·······················································································68
15. 말레이시아(Malaysia) ···········································································71
16. 마셜제도(Marshall Islands) ····································································75
17. 마이크로네시아연방(Federated States of Micronesia) ······························78
18. 몰디브(Maldives) ··················································································81
19. 몽골(Mongolia) ····················································································84
20. 미얀마(Myanmar) ·················································································87
21. 나우루(Nauru) ······················································································90
22. 네팔(Nepal) ·························································································93
23. 뉴질랜드(New Zealand) ········································································98
24. 파키스탄(Pakistan) ·············································································103
25. 팔라우(Palau) ····················································································107
26. 파푸아뉴기니(Papua New Guinea :PNG) ·············································110
27. 필리핀(Philippines) ·············································································114
28. 사모아(Samoa) ··················································································118
29. 싱가포르(Singapore) ··········································································121
30. 솔로몬제도(Solomon Islands) ······························································125
31. 스리랑카(Sri Lanka) ···········································································129
32. 태국(Thailand) ···················································································133
33. 동티모르(Timor-Leste) ·······································································137
34. 통가(Tonga) ······················································································140
35. 투발루(Tuvalu) ···················································································143
36. 바누아투(Vanuatu) ·············································································146
37. 베트남(Vietnam) ·················································································149"""

# %%
import re

# 더 간단한 정규식: 숫자. 으로 시작하는 부분과 점선(·) 이후를 잘라냅니다.
countries_with_eng = []
for line in text.strip().split('\n'):
    # 숫자로 시작하는 부분 제거
    name_part = re.sub(r'^\d+\.\s*', '', line)
    # 첫 번째 나타나는 점(·) 앞에서 자르기
    name_part = name_part.split('·')[0].strip()
    countries_with_eng.append(name_part)

print(countries_with_eng)
# Out:
# ['아프가니스탄(Afghanistan)', '호주(Australia)', '방글라데시(Bangladesh)', '부탄(Bhutan)', '브루나이(Brunei)', '캄보디아(Cambodia)', '중국(China)', '쿡제도(Cook Islands)', '피지(Fiji)', '인도(India)', '인도네시아(Indonesia)', '일본(Japan)', '키리바시(Kiribati)', '라오스(Laos)', '말레이시아(Malaysia)', '마셜제도(Marshall Islands)', '마이크로네시아연방(Federated States of Micronesia)', '몰디브(Maldives)', '몽골(Mongolia)', '미얀마(Myanmar)', '나우루(Nauru)', '네팔(Nepal)', '뉴질랜드(New Zealand)', '파키스탄(Pakistan)', '팔라우(Palau)', '파푸아뉴기니(Papua New Guinea :PNG)', '필리핀(Philippines)', '사모아(Samoa)', '싱가포르(Singapore)', '솔로몬제도(Solomon Islands)', '스리랑카(Sri Lanka)', '태국(Thailand)', '동티모르(Timor-Leste)', '통가(Tonga)', '투발루(Tuvalu)', '바누아투(Vanuatu)', '베트남(Vietnam)']

# %%
# 1. 분류 기준 정의 (가나다순 정렬 등에 용이하도록 핵심 단어로 매칭)
east_north_asia_keywords = ['중국', '일본', '몽골']
oceania_keywords = [
    '호주', '쿡제도', '피지', '키리바시', '마셜제도', '마이크로네시아', 
    '나우루', '뉴질랜드', '팔라우', '파푸아뉴기니', '사모아', '솔로몬제도', 
    '통가', '투발루', '바누아투'
]

# 2. 리스트 분류 로직
east_north_asia_list = [c for c in countries_with_eng if any(k in c for k in east_north_asia_keywords)]
oceania_list = [c for c in countries_with_eng if any(k in c for k in oceania_keywords)]

# 3. 나머지를 동남/남아시아로 분류 (위 두 리스트에 포함되지 않은 국가들)
east_south_asia_list = [c for c in countries_with_eng if c not in east_north_asia_list and c not in oceania_list]

# 결과 출력
print(f"✅ 동북아시아 ({len(east_north_asia_list)}개): {east_north_asia_list}\n")
print(f"✅ 오세아니아 ({len(oceania_list)}개): {oceania_list}\n")
print(f"✅ 동남/남아시아 ({len(east_south_asia_list)}개): {east_south_asia_list}")
# Out:
# ✅ 동북아시아 (3개): ['중국(China)', '일본(Japan)', '몽골(Mongolia)']
#
# ✅ 오세아니아 (15개): ['호주(Australia)', '쿡제도(Cook Islands)', '피지(Fiji)', '키리바시(Kiribati)', '마셜제도(Marshall Islands)', '마이크로네시아연방(Federated States of Micronesia)', '나우루(Nauru)', '뉴질랜드(New Zealand)', '팔라우(Palau)', '파푸아뉴기니(Papua New Guinea :PNG)', '사모아(Samoa)', '솔로몬제도(Solomon Islands)', '통가(Tonga)', '투발루(Tuvalu)', '바누아투(Vanuatu)']
#
# ✅ 동남/남아시아 (19개): ['아프가니스탄(Afghanistan)', '방글라데시(Bangladesh)', '부탄(Bhutan)', '브루나이(Brunei)', '캄보디아(Cambodia)', '인도(India)', '인도네시아(Indonesia)', '라오스(Laos)', '말레이시아(Malaysia)', '몰디브(Maldives)', '미얀마(Myanmar)', '네팔(Nepal)', '파키스탄(Pakistan)', '필리핀(Philippines)', '싱가포르(Singapore)', '스리랑카(Sri Lanka)', '태국(Thailand)', '동티모르(Timor-Leste)', '베트남(Vietnam)']

# %% [markdown]
# #### 미주지역

# %%
text = """1. 앤티가바부다(Antigua and Barbuda) ·····················································154
2. 아르헨티나(Argentina) ··········································································157
3. 바하마(Bahamas) ·················································································161
4. 바베이도스(Barbados) ··········································································164
5. 벨리즈(Belize) ······················································································168
6. 볼리비아(Bolivia) ··················································································171
7. 브라질(Brazil) ·······················································································175
8. 캐나다(Canada) ···················································································180
9. 칠레(Chile) ··························································································185
10. 콜롬비아(Colombia) ············································································189
11. 코스타리카(Costa Rica) ······································································194
12. 쿠바(Cuba)* ······················································································199
13. 도미니카연방(Dominica) ······································································202
14. 도미니카공화국(Dominican Republic) ···················································205
15. 에콰도르(Ecuador) ·············································································209
16. 엘살바도르(El Salvador) ······································································213
17. 그레나다(Grenada) ·············································································218
18. 과테말라(Guatemala) ··········································································221
19. 가이아나(Guyana) ··············································································225
20. 아이티(Haiti) ······················································································229
21. 온두라스(Honduras) ···········································································232
22. 자메이카(Jamaica) ·············································································236
23. 멕시코(Mexico) ··················································································240
24. 니카라과(Nicaragua) ··········································································244
25. 파나마(Panama) ················································································248
26. 파라과이(Paraguay) ···········································································253
27. 페루(Peru) ·························································································257
28. 세인트 키츠 네비스(St. Kitts-Nevis) ·····················································262
29. 세인트 루시아(St. Lucia) ·····································································265
30. 세인트 빈센트 그레나딘(St. Vincent & the Grenadines) ·························268
31. 수리남(Suriname) ···············································································271
32. 트리니다드토바고(Trinidad & Tobago) ·················································275
33. 우루과이(Uruguay) ·············································································279
34. 미국(United States of America) ···························································283
35. 베네수엘라(Venezuela) ·······································································289"""

# %%
import re

# 더 간단한 정규식: 숫자. 으로 시작하는 부분과 점선(·) 이후를 잘라냅니다.
countries_with_eng = []
for line in text.strip().split('\n'):
    # 숫자로 시작하는 부분 제거
    name_part = re.sub(r'^\d+\.\s*', '', line)
    # 첫 번째 나타나는 점(·) 앞에서 자르기
    name_part = name_part.split('·')[0].strip()
    countries_with_eng.append(name_part)

print(countries_with_eng)
# Out:
# ['앤티가바부다(Antigua and Barbuda)', '아르헨티나(Argentina)', '바하마(Bahamas)', '바베이도스(Barbados)', '벨리즈(Belize)', '볼리비아(Bolivia)', '브라질(Brazil)', '캐나다(Canada)', '칠레(Chile)', '콜롬비아(Colombia)', '코스타리카(Costa Rica)', '쿠바(Cuba)*', '도미니카연방(Dominica)', '도미니카공화국(Dominican Republic)', '에콰도르(Ecuador)', '엘살바도르(El Salvador)', '그레나다(Grenada)', '과테말라(Guatemala)', '가이아나(Guyana)', '아이티(Haiti)', '온두라스(Honduras)', '자메이카(Jamaica)', '멕시코(Mexico)', '니카라과(Nicaragua)', '파나마(Panama)', '파라과이(Paraguay)', '페루(Peru)', '세인트 키츠 네비스(St. Kitts-Nevis)', '세인트 루시아(St. Lucia)', '세인트 빈센트 그레나딘(St. Vincent & the Grenadines)', '수리남(Suriname)', '트리니다드토바고(Trinidad & Tobago)', '우루과이(Uruguay)', '미국(United States of America)', '베네수엘라(Venezuela)']

# %%
# 남미 대륙에 속하는 국가 키워드 (분류 기준)
south_america_keywords = [
    '아르헨티나', '볼리비아', '브라질', '칠레', '콜롬비아', '에콰도르', 
    '가이아나', '파라과이', '페루', '수리남', '우루과이', '베네수엘라'
]

# 리스트 컴프리헨션을 이용한 분류
south_america_list = [c for c in countries_with_eng if any(key in c for key in south_america_keywords)]
north_america_list = [c for c in countries_with_eng if c not in south_america_list]

# 결과 출력
print(f"🌎 북미/중미 리스트 ({len(north_america_list)}개):")
print(north_america_list)
print(f"🌎 남미 리스트 ({len(south_america_list)}개):")
print(south_america_list)
# Out:
# 🌎 북미/중미 리스트 (23개):
# ['앤티가바부다(Antigua and Barbuda)', '바하마(Bahamas)', '바베이도스(Barbados)', '벨리즈(Belize)', '캐나다(Canada)', '코스타리카(Costa Rica)', '쿠바(Cuba)*', '도미니카연방(Dominica)', '도미니카공화국(Dominican Republic)', '엘살바도르(El Salvador)', '그레나다(Grenada)', '과테말라(Guatemala)', '아이티(Haiti)', '온두라스(Honduras)', '자메이카(Jamaica)', '멕시코(Mexico)', '니카라과(Nicaragua)', '파나마(Panama)', '세인트 키츠 네비스(St. Kitts-Nevis)', '세인트 루시아(St. Lucia)', '세인트 빈센트 그레나딘(St. Vincent & the Grenadines)', '트리니다드토바고(Trinidad & Tobago)', '미국(United States of America)']
#
# 🌎 남미 리스트 ({len(south_america_list)}개):
# ['아르헨티나(Argentina)', '볼리비아(Bolivia)', '브라질(Brazil)', '칠레(Chile)', '콜롬비아(Colombia)', '에콰도르(Ecuador)', '가이아나(Guyana)', '파라과이(Paraguay)', '페루(Peru)', '수리남(Suriname)', '우루과이(Uruguay)', '베네수엘라(Venezuela)']

# %% [markdown]
# #### 중동지역

# %%
text = """1. 알제리(Algeria) ····················································································494
2. 바레인(Bahrain) ···················································································498
3. 이집트(Egypt) ······················································································502
4. 이란(Iran) ····························································································506
5. 이라크(Iraq) ·························································································511
6. 이스라엘(Israel) ····················································································515
7. 요르단(Jordan) ····················································································520
8. 쿠웨이트(Kuwait) ··················································································525
9. 레바논(Lebanon) ·················································································529
10. 리비아(Libya) ·····················································································532
11. 모리타니아(Mauritania) ·······································································536
12. 모로코(Morocco) ················································································539
13. 오만(Oman) ·······················································································543
14. 카타르(Qatar) ·····················································································547
15. 사우디아라비아(Saudi Arabia) ·····························································551
16. 시리아(Syria)* ····················································································555
17. 튀니지(Tunisia) ··················································································558
18. 아랍에미리트(United Arab Emirates : UAE) ··········································562
19. 예멘(Yemen) ·····················································································566"""

# %%
import re

# 더 간단한 정규식: 숫자. 으로 시작하는 부분과 점선(·) 이후를 잘라냅니다.
countries_with_eng = []
for line in text.strip().split('\n'):
    # 숫자로 시작하는 부분 제거
    name_part = re.sub(r'^\d+\.\s*', '', line)
    # 첫 번째 나타나는 점(·) 앞에서 자르기
    name_part = name_part.split('·')[0].strip()
    countries_with_eng.append(name_part)

print(countries_with_eng)
# Out:
# ['알제리(Algeria)', '바레인(Bahrain)', '이집트(Egypt)', '이란(Iran)', '이라크(Iraq)', '이스라엘(Israel)', '요르단(Jordan)', '쿠웨이트(Kuwait)', '레바논(Lebanon)', '리비아(Libya)', '모리타니아(Mauritania)', '모로코(Morocco)', '오만(Oman)', '카타르(Qatar)', '사우디아라비아(Saudi Arabia)', '시리아(Syria)*', '튀니지(Tunisia)', '아랍에미리트(United Arab Emirates : UAE)', '예멘(Yemen)']

# %%
# 1. 각 카테고리별 매핑 정의 (키워드 매칭 방식)
maghreb_list = [c for c in countries_with_eng if any(k in c for k in ['알제리', '리비아', '모리타니아', '모로코', '튀니지'])]
arabian_peninsula_list = [c for c in countries_with_eng if any(k in c for k in ['바레인', '쿠웨이트', '오만', '카타르', '사우디', '아랍에미리트', '예멘'])]
levant_list = [c for c in countries_with_eng if any(k in c for k in ['이라크', '요르단', '레바논', '시리아', '이집트'])] # 이집트는 종종 포함되거나 별도로 분류됨
jewish_list = [c for c in countries_with_eng if '이스라엘' in c]
persian_list = [c for c in countries_with_eng if '이란' in c]
turkic_list = [c for c in countries_with_eng if '터키' in c] # 현재 원본 리스트에는 없음

# 결과 확인을 위한 출력
categories = {
    "Maghreb (마그레브)": maghreb_list,
    "Arabian Peninsula (아라비아 반도)": arabian_peninsula_list,
    "Levant (레반트)": levant_list,
    "Jewish (유대)": jewish_list,
    "Persian (페르시아)": persian_list,
    "Turkic (투르크)": turkic_list
}

for name, items in categories.items():
    print(f"## {name}")
    print(f"{items}\n")
# Out:
# ## Maghreb (마그레브)
# ['알제리(Algeria)', '리비아(Libya)', '모리타니아(Mauritania)', '모로코(Morocco)', '튀니지(Tunisia)']
#
# ## Arabian Peninsula (아라비아 반도)
# ['바레인(Bahrain)', '쿠웨이트(Kuwait)', '오만(Oman)', '카타르(Qatar)', '사우디아라비아(Saudi Arabia)', '아랍에미리트(United Arab Emirates : UAE)', '예멘(Yemen)']
#
# ## Levant (레반트)
# ['이집트(Egypt)', '이라크(Iraq)', '요르단(Jordan)', '레바논(Lebanon)', '시리아(Syria)*']
#
# ## Jewish (유대)
# ['이스라엘(Israel)']
#
# ## Persian (페르시아)
# ['이란(Iran)']
#
# ## Turkic (투르크)
# []

# %% [markdown]
# #### 아프리카지역

# %%
text = """1. 앙골라(Angola) ···················································································572
2. 베냉(Benin) ························································································576
3. 보츠와나(Botswana) ············································································579
4. 부르키나파소(Burkina Faso) ································································582
5. 부룬디(Burundi) ··················································································585
6. 카메룬(Cameroon) ··············································································588
7. 카보베르데(Cape Verde) ·····································································592
8. 중앙아프리카공화국(Central African Republic) ·······································595
9. 차드(Chad) ························································································598
10. 코모로(Comoros) ···············································································601
11. 콩고공화국(Congo) ············································································604
12. 콩고민주공화국(DR콩고)(Democratic Republic of Congo) ······················607
13. 코트디부아르(Côte D'Ivoire) ·································································611
14. 지부티(Djibouti) ··················································································615
15. 적도기니(Equatorial Guinea) ·······························································618
16. 에스와티니(Eswatini) ··········································································621
16. 에리트레아(Eritrea) ·············································································624
17. 에티오피아(Ethiopia) ···········································································627
18. 가봉(Gabon) ······················································································632
19. 감비아(Gambia) ·················································································636
20. 가나(Ghana) ······················································································639
21. 기니(Guinea) ·····················································································643
22. 기니비사우(Guinea-Bissau) ································································646
23. 케냐(Kenya) ······················································································649
24. 레소토(Lesotho) ·················································································653
25. 라이베리아(Liberia) ············································································656
26. 마다가스카르(Madagascar) ·································································659
27. 말라위(Malawi) ···················································································662
28. 말리(Mali) ··························································································665
29. 모리셔스(Mauritius) ············································································668
30. 모잠비크(Mazambique) ·······································································671
31. 나미비아(Namibia) ··············································································674
32. 니제르(Niger) ·····················································································677
33. 나이지리아(Nigeria) ············································································680
34. 르완다(Rwanda) ·················································································684
35. 상투메프린시페(Sâo Tomé & Principe) ················································688
36. 세네갈(Senegal) ·················································································691
37. 세이셸(Seychelles) ·············································································695
38. 시에라리온(Sierra Leone) ···································································698
39. 소말리아(Somalia) ··············································································701
40. 남아프리카공화국(South Africa) ···························································704
41. 남수단(South Sudan) ··········································································708
42. 수단(Sudan) ······················································································712
44. 탄자니아(Tanzania) ············································································718
45. 토고(Togo) ························································································722
46. 우간다(Uganda) ·················································································725
47. 잠비아(Zambia) ··················································································730
48. 짐바브웨(Zimbabwe) ··········································································733
"""

# %%
import re

# 더 간단한 정규식: 숫자. 으로 시작하는 부분과 점선(·) 이후를 잘라냅니다.
countries_with_eng = []
for line in text.strip().split('\n'):
    # 숫자로 시작하는 부분 제거
    name_part = re.sub(r'^\d+\.\s*', '', line)
    # 첫 번째 나타나는 점(·) 앞에서 자르기
    name_part = name_part.split('·')[0].strip()
    countries_with_eng.append(name_part)

print(countries_with_eng)
# Out:
# ['앙골라(Angola)', '베냉(Benin)', '보츠와나(Botswana)', '부르키나파소(Burkina Faso)', '부룬디(Burundi)', '카메룬(Cameroon)', '카보베르데(Cape Verde)', '중앙아프리카공화국(Central African Republic)', '차드(Chad)', '코모로(Comoros)', '콩고공화국(Congo)', '콩고민주공화국(DR콩고)(Democratic Republic of Congo)', "코트디부아르(Côte D'Ivoire)", '지부티(Djibouti)', '적도기니(Equatorial Guinea)', '에스와티니(Eswatini)', '에리트레아(Eritrea)', '에티오피아(Ethiopia)', '가봉(Gabon)', '감비아(Gambia)', '가나(Ghana)', '기니(Guinea)', '기니비사우(Guinea-Bissau)', '케냐(Kenya)', '레소토(Lesotho)', '라이베리아(Liberia)', '마다가스카르(Madagascar)', '말라위(Malawi)', '말리(Mali)', '모리셔스(Mauritius)', '모잠비크(Mazambique)', '나미비아(Namibia)', '니제르(Niger)', '나이지리아(Nigeria)', '르완다(Rwanda)', '상투메프린시페(Sâo Tomé & Principe)', '세네갈(Senegal)', '세이셸(Seychelles)', '시에라리온(Sierra Leone)', '소말리아(Somalia)', '남아프리카공화국(South Africa)', '남수단(South Sudan)', '수단(Sudan)', '탄자니아(Tanzania)', '토고(Togo)', '우간다(Uganda)', '잠비아(Zambia)', '짐바브웨(Zimbabwe)']

# %%
# 지역별 분류 기준 정의
regions = {
    "north": ['수단(Sudan)'], # 주신 리스트 내 북아프리카 국가는 수단이 유일 (이집트, 리비아 등은 리스트에 없음)
    "west": ['베냉(Benin)', '부르키나파소(Burkina Faso)', '카보베르데(Cape Verde)', "코트디부아르(Côte D'Ivoire)", '감비아(Gambia)', '가나(Ghana)', '기니(Guinea)', '기니비사우(Guinea-Bissau)', '라이베리아(Liberia)', '말리(Mali)', '니제르(Niger)', '나이지리아(Nigeria)', '세네갈(Senegal)', '시에라리온(Sierra Leone)', '토고(Togo)'],
    "east": ['부룬디(Burundi)', '코모로(Comoros)', '지부티(Djibouti)', '에리트레아(Eritrea)', '에티오피아(Ethiopia)', '케냐(Kenya)', '마다가스카르(Madagascar)', '말라위(Malawi)', '모리셔스(Mauritius)', '모잠비크(Mazambique)', '르완다(Rwanda)', '세이셸(Seychelles)', '소말리아(Somalia)', '남수단(South Sudan)', '탄자니아(Tanzania)', '우간다(Uganda)', '잠비아(Zambia)', '짐바브웨(Zimbabwe)'],
    "central": ['카메룬(Cameroon)', '중앙아프리카공화국(Central African Republic)', '차드(Chad)', '콩고공화국(Congo)', '콩고민주공화국(DR콩고)(Democratic Republic of Congo)', '적도기니(Equatorial Guinea)', '가봉(Gabon)', '상투메프린시페(Sâo Tomé & Principe)', '앙골라(Angola)'],
    "south": ['보츠와나(Botswana)', '에스와티니(Eswatini)', '레소토(Lesotho)', '나미비아(Namibia)', '남아프리카공화국(South Africa)']
}

# 리스트 초기화
north_africa_list = []
west_africa_list = []
east_africa_list = []
south_africa_list = []
central_africa_list = []

# 분류 로직
for country in countries_with_eng:
    if country in regions["north"]:
        north_africa_list.append(country)
    elif country in regions["west"]:
        west_africa_list.append(country)
    elif country in regions["east"]:
        east_africa_list.append(country)
    elif country in regions["central"]:
        central_africa_list.append(country)
    elif country in regions["south"]:
        south_africa_list.append(country)

# 결과 출력 확인
print(f"북아프리카: {north_africa_list}")
print(f"서아프리카: {west_africa_list}")
print(f"동아프리카: {east_africa_list}")
print(f"중앙아프리카: {central_africa_list}")
print(f"남아프리카: {south_africa_list}")
# Out:
# 북아프리카: ['수단(Sudan)']
# 서아프리카: ['베냉(Benin)', '부르키나파소(Burkina Faso)', '카보베르데(Cape Verde)', "코트디부아르(Côte D'Ivoire)", '감비아(Gambia)', '가나(Ghana)', '기니(Guinea)', '기니비사우(Guinea-Bissau)', '라이베리아(Liberia)', '말리(Mali)', '니제르(Niger)', '나이지리아(Nigeria)', '세네갈(Senegal)', '시에라리온(Sierra Leone)', '토고(Togo)']
# 동아프리카: ['부룬디(Burundi)', '코모로(Comoros)', '지부티(Djibouti)', '에리트레아(Eritrea)', '에티오피아(Ethiopia)', '케냐(Kenya)', '마다가스카르(Madagascar)', '말라위(Malawi)', '모리셔스(Mauritius)', '모잠비크(Mazambique)', '르완다(Rwanda)', '세이셸(Seychelles)', '소말리아(Somalia)', '남수단(South Sudan)', '탄자니아(Tanzania)', '우간다(Uganda)', '잠비아(Zambia)', '짐바브웨(Zimbabwe)']
# 중앙아프리카: ['앙골라(Angola)', '카메룬(Cameroon)', '중앙아프리카공화국(Central African Republic)', '차드(Chad)', '콩고공화국(Congo)', '콩고민주공화국(DR콩고)(Democratic Republic of Congo)', '적도기니(Equatorial Guinea)', '가봉(Gabon)', '상투메프린시페(Sâo Tomé & Principe)']
# 남아프리카: ['보츠와나(Botswana)', '에스와티니(Eswatini)', '레소토(Lesotho)', '나미비아(Namibia)', '남아프리카공화국(South Africa)']

# %% [markdown]
# #### 특수지역

# %%
text = """1. 앵귈라(Anguilla) ···················································································740
2. 아루바(Aruba) ······················································································741
3. 건지(Bailiwick of Guernsey) ··································································742
4. 저지(Bailiwick of Jersey) ······································································743
5. 버뮤다(Bermuda) ·················································································744
6. 영국령 남극지역(British Antarctic Territory) ·············································745
7. 영국령 인도양 제도(British Indian Ocean Territory) ·································746
8. 영국령 버진 아일랜드(British Virgin Islands) ···········································747
9. 케이맨제도(Cayman Islands) ·································································748
10. 프랑스령 기아나(French Guiana) ·························································749
11. 프랑스령 폴리네시아(French Polynesia) ···············································750
12. 지브롤터(Gibraltar) ·············································································751 
13. 그린란드(Greenland) ··········································································752
14. 과들루프(Guadeloupe) ·······································································753
15. 괌(Guam) ··························································································754
16. 맨 섬(Isle of Man) ··············································································755
17. 마르티니크(Martinique) ·······································································756
18. 마요트(Mayotte) ·················································································757
19. 몬트세랫(Montserrat) ··········································································758
20. 네덜란드령 안틸레스(Netherlands Antilles) ···········································759
21. 뉴 칼레도니아(New Caledonia) ···························································760
22. 니우에(Niue) ······················································································761
23. 북마리아나 군도(Northern Mariana Islands) ··········································762
24. 팔레스타인(Palestine) ·········································································763
25. 핏케언 섬(Pitcairn Islands) ··································································766
26. 레위니옹(Réunion) ·············································································767
27. 사하라 아랍민주공화국(서부사하라)(Sahara Arab Democratic Republic) ····768
28. 세인트 헬레나 섬(St Helena) ·······························································770
29. 생피에르･미클롱(St. Pierre and Miquelon) ···········································771
30. 타이완(Taiwan) ··················································································772
31. 터크스･케이커스 제도(Turks and Caicos Islands) ·································776
32. 왈리스･퓌튀나(Wallis and Futuna) ·······················································777

"""

# %%
import re

# 더 간단한 정규식: 숫자. 으로 시작하는 부분과 점선(·) 이후를 잘라냅니다.
countries_with_eng = []
for line in text.strip().split('\n'):
    # 숫자로 시작하는 부분 제거
    name_part = re.sub(r'^\d+\.\s*', '', line)
    # 첫 번째 나타나는 점(·) 앞에서 자르기
    name_part = name_part.split('·')[0].strip()
    countries_with_eng.append(name_part)

print(countries_with_eng)
# Out:
# ['앵귈라(Anguilla)', '아루바(Aruba)', '건지(Bailiwick of Guernsey)', '저지(Bailiwick of Jersey)', '버뮤다(Bermuda)', '영국령 남극지역(British Antarctic Territory)', '영국령 인도양 제도(British Indian Ocean Territory)', '영국령 버진 아일랜드(British Virgin Islands)', '케이맨제도(Cayman Islands)', '프랑스령 기아나(French Guiana)', '프랑스령 폴리네시아(French Polynesia)', '지브롤터(Gibraltar)', '그린란드(Greenland)', '과들루프(Guadeloupe)', '괌(Guam)', '맨 섬(Isle of Man)', '마르티니크(Martinique)', '마요트(Mayotte)', '몬트세랫(Montserrat)', '네덜란드령 안틸레스(Netherlands Antilles)', '뉴 칼레도니아(New Caledonia)', '니우에(Niue)', '북마리아나 군도(Northern Mariana Islands)', '팔레스타인(Palestine)', '핏케언 섬(Pitcairn Islands)', '레위니옹(Réunion)', '사하라 아랍민주공화국(서부사하라)(Sahara Arab Democratic Republic)', '세인트 헬레나 섬(St Helena)', '생피에르･미클롱(St. Pierre and Miquelon)', '타이완(Taiwan)', '터크스･케이커스 제도(Turks and Caicos Islands)', '왈리스･퓌튀나(Wallis and Futuna)']

# %%
# 분류 기준 정의
regions = {
    "아메리카/카리브해": ["Anguilla", "Aruba", "Bermuda", "Virgin Islands", "Cayman", "French Guiana", "Guadeloupe", "Martinique", "Montserrat", "Netherlands Antilles", "St. Pierre and Miquelon", "Turks and Caicos"],
    "유럽": ["Guernsey", "Jersey", "Gibraltar", "Isle of Man"],
    "오세아니아/태평양": ["French Polynesia", "Guam", "New Caledonia", "Niue", "Northern Mariana Islands", "Pitcairn", "Wallis and Futuna"],
    "아시아/중동": ["Taiwan", "Palestine", "British Indian Ocean Territory"],
    "아프리카": ["Mayotte", "Réunion", "Sahara", "St Helena"],
    "기타/남극": ["Antarctic"]
}

# 분류 결과를 담을 딕셔너리
classified_data = {region: [] for region in regions.keys()}
classified_data["미분류"] = []

# 분류 로직
for country in countries_with_eng:
    found = False
    for region, keywords in regions.items():
        if any(key in country for key in keywords):
            classified_data[region].append(country)
            found = True
            break
    if not found:
        classified_data["미분류"].append(country)

# 결과 출력
for region, countries in classified_data.items():
    if countries:
        print(f"## {region} ({len(countries)}개)")
        for c in countries:
            print(f"- {c}")
        print()
# Out:
# ## 아메리카/카리브해 (12개)
# - 앵귈라(Anguilla)
# - 아루바(Aruba)
# - 버뮤다(Bermuda)
# - 영국령 버진 아일랜드(British Virgin Islands)
# - 케이맨제도(Cayman Islands)
# - 프랑스령 기아나(French Guiana)
# - 과들루프(Guadeloupe)
# - 마르티니크(Martinique)
# - 몬트세랫(Montserrat)
# - 네덜란드령 안틸레스(Netherlands Antilles)
# - 생피에르･미클롱(St. Pierre and Miquelon)
# - 터크스･케이커스 제도(Turks and Caicos Islands)
#
# ## 유럽 (4개)
# - 건지(Bailiwick of Guernsey)
# - 저지(Bailiwick of Jersey)
# - 지브롤터(Gibraltar)
# - 맨 섬(Isle of Man)
#
# ## 오세아니아/태평양 (7개)
# - 프랑스령 폴리네시아(French Polynesia)
# - 괌(Guam)
# - 뉴 칼레도니아(New Caledonia)
# - 니우에(Niue)
# - 북마리아나 군도(Northern Mariana Islands)
# - 핏케언 섬(Pitcairn Islands)
# - 왈리스･퓌튀나(Wallis and Futuna)
#
# ## 아시아/중동 (3개)
# - 영국령 인도양 제도(British Indian Ocean Territory)
# - 팔레스타인(Palestine)
# - 타이완(Taiwan)
#
# ## 아프리카 (4개)
# - 마요트(Mayotte)
# - 레위니옹(Réunion)
# - 사하라 아랍민주공화국(서부사하라)(Sahara Arab Democratic Republic)
# - 세인트 헬레나 섬(St Helena)
#
# ## 기타/남극 (1개)
# - 영국령 남극지역(British Antarctic Territory)
#
# ## 미분류 (1개)
# - 그린란드(Greenland)
